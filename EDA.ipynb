# %% [markdown]
# #                     House Price Prediction Report with Source Code

# %% [markdown]
# Complete Exploratory data analysis report is given <a href="https://sai-sujan.github.io/House-Price-Predition/#">here</a>

# %% [markdown]
# ## What is Linear Regression Model in Machine Learning?

# %% [markdown]
# Linear Regression is a Supervised Machine Learning Model for finding the relationship between independent variables and dependent variable. Linear regression performs the task to predict the response (dependent) variable value (y) based on a given (independent) explanatory variable (x). So, this regression technique finds out a linear relationship between x (input) and y (output).

# %% [markdown]
# ## About House Prediction Data Set

# %% [markdown]
# Problem Statement-House Price prediction using Machine learning

# %% [markdown]
# The dataset contains 7 columns and 5000 rows with CSV extension. The data contains the following columns :

# %% [markdown]
# * ‘Avg. Area Income’ – Avg. The income of the householder of the city house is located.

# %% [markdown]
# * ‘Avg. Area House Age’ – Avg. Age of Houses in the same city.

# %% [markdown]
# * ‘Avg. Area Number of Rooms’ – Avg. Number of Rooms for Houses in the same city.

# %% [markdown]
# * ‘Avg. Area Number of Bedrooms’ – Avg. Number of Bedrooms for Houses in the same city.

# %% [markdown]
# * ‘Area Population’ – Population of the city.

# %% [markdown]
# * ‘Price’ – Price that the house sold at.

# %% [markdown]
# * ‘Address’ – Address of the houses.

# %% [markdown]
# ## * Predicting house prices with linear regression using SciKit-Learn, Pandas, Seaborn and NumPy

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# Install the required libraries and setup for the environment for the project. We will be importing SciKit-Learn, Pandas, Seaborn, Matplotlib and Numpy.

# %% [markdown]
# ### Importing Data and Checking out.

# %%
HouseDF.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
HouseDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
HouseDF.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %% [markdown]
# ## Exploratory Data Analysis for House Price Prediction

# %% [markdown]
# Complete Exploratory data analysis report is given <a href="https://sai-sujan.github.io/House-Price-Predition/#">here</a>

# %%
sns.pairplot(HouseDF)

# %%
sns.heatmap(HouseDF.corr(), annot=True)

# %% [markdown]
# ## Training a Linear Regression Model
#
# ### X and y List

# %% [markdown]
# Now begin to train out the regression model. We will need to first split up our data into an X list that contains the features to train on, and a y list with the target variable, in this case, the Price column. We will ignore the Address column because it only has text which is not useful for linear regression modeling.

# %% [markdown]
# ### Split Data into Train, Test

# %% [markdown]
# Now we will split our dataset into a training set and testing set using sklearn train_test_split(). the training set will be going to use for training the model and testing set for testing the model. We are creating a split of 40% training data and 60% of the training set.

# %% [markdown]
# X_train and y_train contain data for the training model. X_test and y_test contain data for the testing model. X and y are features and target variable names.

# %% [markdown]
# ## Creating and Training the LinearRegression Model

# %% [markdown]
# We will import and create sklearn linearmodel LinearRegression object and fit the training dataset in it.

# %% [markdown]
# ## LinearRegression Model Evaluation

# %% [markdown]
# Now let’s evaluate the model by checking out its coefficients and how we can interpret them.

# %%
print(lm.intercept_)
# Out:
# -2640159.7968526953

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                 Coefficient
# Avg. Area Income                  21.528276
# Avg. Area House Age           164883.282027
# Avg. Area Number of Rooms     122368.678027
# Avg. Area Number of Bedrooms    2233.801864
# Area Population                   15.150420

# %% [markdown]
# What does coefficient of data says:
#
# * Holding all other features fixed, a 1 unit increase in Avg. Area Income is associated with an increase of 21.52 .
# * Holding all other features fixed, a 1 unit increase in Avg. Area House Age is associated with an increase of 164883.28 .
# * Holding all other features fixed, a 1 unit increase in Avg. Area Number of Rooms is associated with an increase of $122368.67 .
# * Holding all other features fixed, a 1 unit increase in Avg. Area Number of Bedrooms is associated with an increase of $2233.80 .
# * Holding all other features fixed, a 1 unit increase in Area Population is associated with an increase of $15.15 .

# %% [markdown]
# ## Predictions from our Linear Regression Model

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# In the above scatter plot, we see data is in line shape, which means our model has done good predictions.

# %%
sns.distplot((y_test-predictions),bins=50)
# Out:
# C:\Users\SAI SUJAN\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SAI SUJAN\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\SAI SUJAN\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\SAI SUJAN\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# ## Check the Testing Accuracy

# %%
score
# Out:
# 0.9176824009649241

# %% [markdown]
# ## Check the Training Accuracy

# %%
score
# Out:
# 0.9181223200568411

# %% [markdown]
# # Conclusion

# %% [markdown]
# We have created a Linear Regression Model which we help the real state agent for estimating the house price with 91% accuracy.
